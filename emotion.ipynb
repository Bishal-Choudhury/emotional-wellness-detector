# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB 9.8 MB/s eta 0:04:13
#      ---------------------------------------- 0.0/2.5 GB 11.0 MB/s eta 0:03:45
#      ---------------------------------------- 0.0/2.5 GB 12.5 MB/s eta 0:03:19
#      ---------------------------------------- 0.0/2.5 GB 11.3 MB/s eta 0:03:40
#      ---------------------------------------- 0.0/2.5 GB 11.4 MB/s eta 0:03:38
#      ---------------------------------------- 0.0/2.5 GB 11.5 MB/s eta 0:03:36
#      ---------------------------------------- 0.0/2.5 GB 11.5 MB/s eta 0:03:34
#      ---------------------------------------- 0.0/2.5 GB 11.7 MB/s eta 0:03:31
#      ---------------------------------------- 0.0/2.5 GB 11.4 MB/s eta 0:03:37
#      ---------------------------------------- 0.0/2.5 GB 11.7 MB/s eta 0:03:31
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
# !cd yolov5 && pip install -r requirements.txt
# Out:
# ...
#   Obtaining dependency information for gitpython>=3.1.30 from https://files.pythonhosted.org/packages/8d/c4/82b858fb6483dfb5e338123c154d19c043305b01726a67d89532b8f8f01b/GitPython-3.1.40-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for opencv-python>=4.1.1 from https://files.pythonhosted.org/packages/38/d2/3e8c13ffc37ca5ebc6f382b242b44acb43eb489042e1728407ac3904e72f/opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for ultralytics>=8.0.147 from https://files.pythonhosted.org/packages/f4/79/b192c64e13eefc7f8543a10080767ab057850fa9bdbc38e7c261a3432c93/ultralytics-8.0.227-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for gitdb<5,>=4.0.1 from https://files.pythonhosted.org/packages/fd/5b/8f0c4a5bb9fd491c277c21eff7ccae71b47d43c4446c9d0c6cff2fe8c2c4/gitdb-4.0.11-py3-none-any.whl.metadata
# ...

# %%
import sys
print(sys.version)
# Out:
# 3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\User/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-12-16 Python-3.11.5 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
results.render()
# Out:
# [array([[[72, 48, 38],
#          [74, 50, 40],
#          [73, 51, 40],
#          ...,
#          [56, 21, 25],
#          [55, 19, 21],
#          [51, 15, 17]],
#
#         [[71, 47, 37],
#          [71, 47, 37],
#          [70, 48, 37],
#          ...,
#          [55, 20, 24],
#          [52, 16, 18],
#          [47, 11, 13]],
#
#         [[75, 51, 41],
#          [73, 49, 39],
#          [70, 48, 37],
#          ...,
#          [56, 20, 24],
#          [52, 16, 20],
#          [48, 12, 16]],
#
#         ...,
#
#         [[40, 43, 48],
#          [41, 44, 49],
#          [40, 43, 48],
#          ...,
#          [35, 49, 49],
#          [35, 49, 49],
#          [36, 50, 50]],
#
#         [[39, 42, 49],
#          [39, 42, 49],
#          [39, 42, 49],
#          ...,
#          [35, 49, 50],
#          [35, 49, 50],
#          [36, 50, 51]],
#
#         [[38, 41, 48],
#          [38, 41, 48],
#          [38, 41, 48],
#          ...,
#          [35, 49, 50],
# ...

# %%
img = 'https://www.its.ucla.edu/wp-content/uploads/sites/6/2018/01/los-angeles-1396606_960_720-600x384.jpg'

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 384x600 19 cars, 6 trucks
# Speed: 2028.1ms pre-process, 206.2ms inference, 528.1ms NMS per image at shape (1, 3, 416, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
import uuid   # Unique identifier
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images') #/data/images
labels = ['well', 'not well']
number_imgs = 10

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    # Loop through image range
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        # Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        # Writes out image to file 
        cv2.imwrite(imgname, frame)
        
        # Render to the screen
        cv2.imshow('Image Collection', frame)
        
        # 2 second delay between captures
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %%
print(os.path.join(IMAGES_PATH, labels[0]+'.'+str(uuid.uuid1())+'.jpg'))
# Out:
# data\images\well.bf55536a-9ca0-11ee-81eb-5291e3fc24fe.jpg

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# ...
# data\images\well.c16b7ec8-9ca0-11ee-8f19-5291e3fc24fe.jpg
# ...
# data\images\well.c16b7ec9-9ca0-11ee-98f5-5291e3fc24fe.jpg
# ...
# data\images\well.c16b7eca-9ca0-11ee-86b0-5291e3fc24fe.jpg
# ...
# data\images\well.c16b7ecb-9ca0-11ee-882f-5291e3fc24fe.jpg
# ...
# data\images\well.c16ba62f-9ca0-11ee-a8fb-5291e3fc24fe.jpg
# ...
# data\images\well.c16ba630-9ca0-11ee-8211-5291e3fc24fe.jpg
# ...
# data\images\well.c16ba631-9ca0-11ee-a58b-5291e3fc24fe.jpg
# ...
# data\images\well.c16ba632-9ca0-11ee-b038-5291e3fc24fe.jpg
# ...
# data\images\well.c16ba633-9ca0-11ee-accb-5291e3fc24fe.jpg
# ...
# data\images\well.c16ba634-9ca0-11ee-b87e-5291e3fc24fe.jpg
# ...
# data\images\not well.c16ba635-9ca0-11ee-b156-5291e3fc24fe.jpg
# ...
# data\images\not well.c16ba636-9ca0-11ee-817d-5291e3fc24fe.jpg
# ...
# data\images\not well.c16ba637-9ca0-11ee-8182-5291e3fc24fe.jpg
# ...
# data\images\not well.c16ba638-9ca0-11ee-b47d-5291e3fc24fe.jpg
# ...
# data\images\not well.c16ba639-9ca0-11ee-a05a-5291e3fc24fe.jpg
# ...
# data\images\not well.c16ba63a-9ca0-11ee-b600-5291e3fc24fe.jpg
# ...

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# Cloning into 'labelImg'...

# %%
# CMD
# python -m venv venv
# Set-ExecutionPolicy -Scope Process -ExecutionPolicy Bypass
# .\venv\Scripts\Activate
# pip install pyqt5 lxml --upgrade
# .\venv\Scripts\pyrcc5.exe -o libs/resources.py resources.qrc
# cd C:\Users\User\Notebook\labelImg
# python labelImg.py

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yaml --weights yolov5s.pt --workers 2
# Out:
# ^C

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp3/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\User/.cache\torch\hub\master.zip
# YOLOv5  2023-12-17 Python-3.11.5 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('data', 'images', 'not well.7b86de19-9ca0-11ee-8ca4-5291e3fc24fe.jpg')

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 480x640 1 not well
# Speed: 8.6ms pre-process, 74.2ms inference, 15.7ms NMS per image at shape (1, 3, 480, 640)

# %%
img = os.path.join('data', 'images', 'well.6da521ce-9ca0-11ee-91fa-5291e3fc24fe.jpg')

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 480x640 1 well
# Speed: 9.4ms pre-process, 74.6ms inference, 0.0ms NMS per image at shape (1, 3, 480, 640)

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
